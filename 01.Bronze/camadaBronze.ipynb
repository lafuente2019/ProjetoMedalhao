# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/ProjetoMedalhao/00.config/config

# %%
from pyspark.sql.functions import current_date, date_format, col
import requests
import pandas as pd
from datetime import datetime
from pyspark.sql.types import *

# %%
# API do banco Central
URL = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.433/dados'



params = {
    'formato': 'json',
    'dataInicial': '01/01/2024',
    'dataFinal': '31/05/2025' #datetime.now().strftime('%d-%m-%Y')
}
# Chamada da API
response = requests.get(URL, params=params)
data = response.json()

# %%
print(data)

# %%
# Conversão para dataframe
df = spark.createDataFrame(data)

# %%
df.toPandas()

# %%
df = df.toDF('data', 'ipca')
# Converte a coluna 'valor' de string para double (float)
df = df.withColumn("ipca", col("ipca").cast("double"))

# %%
df = df.withColumn("data_coleta", date_format(current_date(), "dd-MM-yyyy"))

# %%
df.display()

# %%
df.printSchema()

# %%
df.write.format("delta").mode("append").saveAsTable("workspace.bronze_etl.ipca")
